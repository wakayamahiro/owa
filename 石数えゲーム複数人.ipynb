# %% [markdown]
# <a href="https://colab.research.google.com/github/wakayamahiro/owa/blob/main/%E7%9F%B3%E6%95%B0%E3%81%88%E3%82%B2%E3%83%BC%E3%83%A0%E8%A4%87%E6%95%B0%E4%BA%BA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def kan(isi,teban,hitob):


  playr=mem[hitob]



  n=0
  while n== 0:
    print(playr,'の人：石の数指定(1～6)')
    a = int(input())

    if isi-a < 0:
      isi=0
      n=1
    else:
      if 0<a and a<6:
        n=1
        isi = isi - a
        teban = teban + 1
      else:

        ns=0
        while ns==0:
          print('もう一度入力：',playr,'の人：石の数指定(1～6)')
          a = int(input())

          if isi-a < 0:
            isi=0
            n=1
          else:
            if 0<a and a<6:
              n=1
              ns=1
              isi = isi - a
              teban = teban + 1
            else:
              print('-------------')


  #print(isi,teban)
  return isi,teban,playr


teban = 0
kai=0
hitob=-1
m=['A','B','C','D','E']
mem=[]



print('参加人数を入力してください(2人～5人)')
memsu = int(input())


for i in range(memsu):
  mem.append(m[i])


mem=mem+mem+mem+mem+mem+mem+mem+mem+mem+mem+mem+mem+mem+mem+mem
mem=mem+mem+mem+mem+mem+mem+mem+mem+mem+mem+mem+mem+mem+mem+mem

#print(mem)






print('最初の石の数を決めてください')
isi = int(input())






print('=============================')
print('今回の石の数は',isi,'個です')
print('=============================')




while kai <= 1:
  hitob = hitob + 1
  isi,teban,playr = kan(isi,teban,hitob)



  if isi>0:
    print('--------------')
    print('石の残り',isi)
    #print(teban,'teban')
    print('--------------')
  elif isi==0:
    print('$$$$$$$$$$$$$$$$$$$$')
    print(playr,'の人の負け')
    print('$$$$$$$$$$$$$$$$$$$$')
    kai=10
  else:
    print(isi,'石のエラー')
    kai=10
